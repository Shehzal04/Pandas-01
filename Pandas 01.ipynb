# %%
import pandas as pd

# %% [markdown]
# #Dataread

# %%
df=pd.read_csv('apple_products.csv')
df
# Out:
#                                          Product Name  Star Rating  Brand  \
# 0                   APPLE iPhone 8 Plus (Gold, 64 GB)          4.6  Apple
# 1            APPLE iPhone 8 Plus (Space Grey, 256 GB)          4.6  Apple
# 2                APPLE iPhone 8 Plus (Silver, 256 GB)          4.6  Apple
# 3                     APPLE iPhone 8 (Silver, 256 GB)          4.6  Apple
# 4                       APPLE iPhone 8 (Gold, 256 GB)          4.6  Apple
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)          4.6  Apple
# 6             APPLE iPhone 8 Plus (Space Grey, 64 GB)          4.6  Apple
# 7                 APPLE iPhone 8 (Space Grey, 256 GB)          4.6  Apple
# 8                 APPLE iPhone XS Max (Silver, 64 GB)          4.6  Apple
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...          4.6  Apple
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...          4.6  Apple
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...          4.6  Apple
# ...

# %% [markdown]
# #DataCleaning

# %%
df.dropna()
# Out:
#                                          Product Name  Star Rating  Brand  \
# 0                   APPLE iPhone 8 Plus (Gold, 64 GB)          4.6  Apple
# 1            APPLE iPhone 8 Plus (Space Grey, 256 GB)          4.6  Apple
# 4                       APPLE iPhone 8 (Gold, 256 GB)          4.6  Apple
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)          4.6  Apple
# 7                 APPLE iPhone 8 (Space Grey, 256 GB)          4.6  Apple
# 8                 APPLE iPhone XS Max (Silver, 64 GB)          4.6  Apple
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...          4.6  Apple
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...          4.6  Apple
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...          4.6  Apple
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...          4.6  Apple
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...          4.7  Apple
# 14             APPLE iPhone 11 Pro Max (Gold, 256 GB)          4.7  Apple
# ...

# %%
df.fillna(999)
# Out:
#                                          Product Name  Star Rating  Brand  \
# 0                   APPLE iPhone 8 Plus (Gold, 64 GB)          4.6  Apple
# 1            APPLE iPhone 8 Plus (Space Grey, 256 GB)          4.6  Apple
# 2                APPLE iPhone 8 Plus (Silver, 256 GB)          4.6  Apple
# 3                     APPLE iPhone 8 (Silver, 256 GB)          4.6  Apple
# 4                       APPLE iPhone 8 (Gold, 256 GB)          4.6  Apple
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)          4.6  Apple
# 6             APPLE iPhone 8 Plus (Space Grey, 64 GB)          4.6  Apple
# 7                 APPLE iPhone 8 (Space Grey, 256 GB)          4.6  Apple
# 8                 APPLE iPhone XS Max (Silver, 64 GB)          4.6  Apple
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...          4.6  Apple
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...          4.6  Apple
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...          4.6  Apple
# ...

# %%
df['Sale Price']
# Out:
# 0      49900.0
# 1      84900.0
# 2          NaN
# 3          NaN
# 4      77000.0
# 5      49900.0
# 6      49900.0
# 7      77000.0
# 8      89900.0
# 9      41999.0
# 10     39999.0
# 11     41999.0
# 12     41999.0
# 13     41999.0
# 14    131900.0
# 15    117100.0
# 16    131900.0
# 17    117100.0
# 18     74999.0
# 19    117900.0
# 20    117100.0
# 21    117900.0
# 22     99900.0
# 23     44999.0
# 24    140900.0
# 25    130900.0
# 26     64900.0
# Name: Sale Price, dtype: float64

# %%
df.loc[3,'Mrp']=6999

# %%
df['Mrp']
# Out:
# 0      49900.0
# 1      84900.0
# 2      84900.0
# 3       6999.0
# 4      77000.0
# 5      49900.0
# 6          NaN
# 7      77000.0
# 8      89900.0
# 9      52900.0
# 10     47900.0
# 11     52900.0
# 12     52900.0
# 13     52900.0
# 14    131900.0
# 15    117100.0
# 16    131900.0
# 17    117100.0
# 18    106600.0
# 19    140300.0
# 20    117100.0
# 21    140300.0
# 22    121300.0
# 23     54900.0
# 24    149900.0
# 25    139900.0
# 26     74900.0
# Name: Mrp, dtype: float64

# %%
df['Mrp'].fillna(897)
# Out:
# 0      49900.0
# 1      84900.0
# 2      84900.0
# 3       6999.0
# 4      77000.0
# 5      49900.0
# 6        897.0
# 7      77000.0
# 8      89900.0
# 9      52900.0
# 10     47900.0
# 11     52900.0
# 12     52900.0
# 13     52900.0
# 14    131900.0
# 15    117100.0
# 16    131900.0
# 17    117100.0
# 18    106600.0
# 19    140300.0
# 20    117100.0
# 21    140300.0
# 22    121300.0
# 23     54900.0
# 24    149900.0
# 25    139900.0
# 26     74900.0
# Name: Mrp, dtype: float64

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# dtype: bool

# %% [markdown]
# #DataSplit

# %%
df[2:5]
# Out:
#                            Product Name  Star Rating  Brand  Sale Price  \
# 2  APPLE iPhone 8 Plus (Silver, 256 GB)          4.6  Apple         NaN
# 3       APPLE iPhone 8 (Silver, 256 GB)          4.6  Apple         NaN
# 4         APPLE iPhone 8 (Gold, 256 GB)          4.6  Apple     77000.0
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews   Ram
# 2  84900.0                    0               3431                356  4 GB
# 3   6999.0                    0              11202                794  5 GB
# 4  77000.0                    0              11202                794  6 GB

# %%
df[1:8:3]
# Out:
#                                Product Name  Star Rating  Brand  Sale Price  \
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)          4.6  Apple     84900.0
# 4             APPLE iPhone 8 (Gold, 256 GB)          4.6  Apple     77000.0
# 7       APPLE iPhone 8 (Space Grey, 256 GB)          4.6  Apple     77000.0
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews   Ram
# 1  84900.0                    0               3431                356  3 GB
# 4  77000.0                    0              11202                794  6 GB
# 7  77000.0                    0              11202                794  9 GB

# %% [markdown]
# #Aggregating data

# %%
print(df['Mrp'].describe())  # Provides statistics like mean, min, max, etc.
# Out:
# count        26.000000
# mean      89084.653846
# std       39258.148544
# min           1.000000
# 25%       52900.000000
# 50%       84900.000000
# 75%      120250.000000
# max      149900.000000
# Name: Mrp, dtype: float64

# %%
df.describe()
# Out:
#        Star Rating     Sale Price            Mrp  Discount Percentage  \
# count    27.000000      25.000000      26.000000            27.000000
# mean      4.651852   83759.720000   89353.807692             7.962963
# std       0.050918   35616.029072   38642.116569             9.382805
# min       4.600000   39999.000000    6999.000000             0.000000
# 25%       4.600000   49900.000000   52900.000000             0.000000
# 50%       4.700000   77000.000000   84900.000000             0.000000
# 75%       4.700000  117100.000000  120250.000000            16.500000
# max       4.700000  140900.000000  149900.000000            29.000000
#
#        Number Of Ratings  Number Of Reviews
# count          27.000000          27.000000
# mean        21531.518519        1822.481481
# std         33367.631177        2853.197294
# min           542.000000          42.000000
# 25%          1078.000000         101.000000
# 50%          3431.000000         356.000000
# ...

# %% [markdown]
# #preprocessing

# %%
df['Normalized_Mrp'] = (df['Mrp'] - df['Mrp'].min()) / (df['Mrp'].max() - df['Mrp'].min())
print("Data normalized. Here's the preview:\n", df[['Mrp', 'Normalized_Mrp']].head())
# Out:
# Data normalized. Here's the preview:
#         Mrp  Normalized_Mrp
# 0  49900.0        0.332884
# 1  84900.0        0.566375
# 2  84900.0        0.566375
# 3      1.0        0.000000
# 4  77000.0        0.513673

# %% [markdown]
# #Data
# Save

# %%
df.to_csv('cleaned_apple_products.csv', index=False)
print("Data saved to 'cleaned_apple_products.csv'.")
# Out:
# Data saved to 'cleaned_apple_products.csv'.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #DataPlot

# %%
plt.plot(df["Mrp"])

# %%
    plt.plot(df['Mrp'], label="MRP")
    plt.title("Price Trend of Apple Products")
    plt.xlabel("Index")
    plt.ylabel("MRP")
    plt.legend()
    plt.show()
